# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pylab
from scipy import misc
from skimage.feature import local_binary_pattern
from skimage.feature import canny
from skimage import io
from skimage import color

# %%
img1 = scipy.ndimage.imread('img1.png')
img2 = scipy.ndimage.imread('img2.png')
img3 = scipy.ndimage.imread('img3.png')
img4 = scipy.ndimage.imread('img4.png')

# %%
plt.figure(1)
plt.subplot(221)
plt.imshow(img1)
plt.subplot(222)
plt.imshow(img2)
plt.subplot(223)
plt.imshow(img3)
plt.subplot(224)
plt.imshow(img4)
plt.show()

# %%
plt.figure(1)

img = scipy.ndimage.imread('img1.png')
R1 = img[:, :, 0]
G1 = img[:, :, 1]
B1 = img[:, :, 2]
img_gray1 = R1 * 299. / 1000 + G1 * 587. / 1000 + B1 * 114. / 1000
img_gray1 = img_gray1.astype('int32')
plt.subplot(221)
plt.imshow(img_gray1, cmap = plt.get_cmap('gray'))

img = scipy.ndimage.imread('img2.png')
R2 = img[:, :, 0]
G2 = img[:, :, 1]
B2 = img[:, :, 2]
img_gray2 = R2 * 299. / 1000 + G2 * 587. / 1000 + B2 * 114. / 1000
img_gray2 = img_gray2.astype('int32')
plt.subplot(222)
plt.imshow(img_gray2, cmap = plt.get_cmap('gray'))

img = scipy.ndimage.imread('img3.png')
R3 = img[:, :, 0]
G3 = img[:, :, 1]
B3 = img[:, :, 2]
img_gray3 = R3 * 299. / 1000 + G3 * 587. / 1000 + B3 * 114. / 1000
img_gray3 = img_gray3.astype('int32')
plt.subplot(223)
plt.imshow(img_gray3, cmap = plt.get_cmap('gray'))

img = scipy.ndimage.imread('img4.png')
R4 = img[:, :, 0]
G4 = img[:, :, 1]
B4 = img[:, :, 2]
img_gray4 = R4 * 299. / 1000 + G4 * 587. / 1000 + B4 * 114. / 1000
img_gray4 = img_gray4.astype('int32')
plt.subplot(224)
plt.imshow(img_gray4, cmap = plt.get_cmap('gray'))

plt.show()

# %%
img_gray3 = img_gray3.astype

# %%
plt.figure(1)
plt.subplot(221)
plt.hist(img_gray1.ravel(), bins='auto', color="grey")  # arguments are passed to np.histogram
plt.subplot(222)
plt.hist(img_gray2.ravel(), bins='auto', color="grey")  # arguments are passed to np.histogram
plt.subplot(223)
plt.hist(img_gray3.ravel(), bins='auto', color="grey")  # arguments are passed to np.histogram
plt.subplot(224)
plt.hist(img_gray4.ravel(), bins='auto', color="grey")  # arguments are passed to np.histogram
plt.show()

# %%
plt.figure(1)
plt.subplot(221)
plt.hist(img_gray1.ravel(), bins='auto', color="grey", normed="True")  # arguments are passed to np.histogram
plt.subplot(222)
plt.hist(img_gray2.ravel(), bins='auto', color="grey", normed="True")  # arguments are passed to np.histogram
plt.subplot(223)
plt.hist(img_gray3.ravel(), bins='auto', color="grey", normed="True")  # arguments are passed to np.histogram
plt.subplot(224)
plt.hist(img_gray4.ravel(), bins='auto', color="grey", normed="True")  # arguments are passed to np.histogram
plt.show()

# %%
plt.figure(1)
plt.subplot(221)
img_red1 = R1.astype('int32')
plt.imshow(img_red1, cmap = plt.get_cmap('Reds'))

plt.subplot(222)
img_red2 = R2.astype('int32')
plt.imshow(img_red2, cmap = plt.get_cmap('Reds'))

plt.subplot(223)
img_red3 = R3.astype('int32')
plt.imshow(img_red3, cmap = plt.get_cmap('Reds'))

plt.subplot(224)
img_red4 = R4.astype('int32')
plt.imshow(img_red4, cmap = plt.get_cmap('Reds'))

plt.show()

# %%
plt.figure(1)
plt.subplot(221)
plt.hist(img_red1.ravel(), bins='auto', color="red", normed="True")  # arguments are passed to np.histogram
plt.subplot(222)
plt.hist(img_red2.ravel(), bins='auto', color="red", normed="True")  # arguments are passed to np.histogram
plt.subplot(223)
plt.hist(img_red3.ravel(), bins='auto', color="red", normed="True")  # arguments are passed to np.histogram
plt.subplot(224)
plt.hist(img_red4.ravel(), bins='auto', color="red", normed="True")  # arguments are passed to np.histogram
plt.show()

# %%
plt.figure(1)
plt.subplot(221)
plt.hist(img_red1.ravel(), bins='auto', color="red")  # arguments are passed to np.histogram
plt.subplot(222)
plt.hist(img_red2.ravel(), bins='auto', color="red")  # arguments are passed to np.histogram
plt.subplot(223)
plt.hist(img_red3.ravel(), bins='auto', color="red")  # arguments are passed to np.histogram
plt.subplot(224)
plt.hist(img_red4.ravel(), bins='auto', color="red")  # arguments are passed to np.histogram
plt.show()

# %%
plt.figure(1)
plt.subplot(221)
img_green1 = G1.astype('int32')
plt.imshow(img_green1, cmap = plt.get_cmap('Greens'))

plt.subplot(222)
img_green2 = G2.astype('int32')
plt.imshow(img_green2, cmap = plt.get_cmap('Greens'))

plt.subplot(223)
img_green3 = G3.astype('int32')
plt.imshow(img_green3, cmap = plt.get_cmap('Greens'))

plt.subplot(224)
img_green4 = G4.astype('int32')
plt.imshow(img_green4, cmap = plt.get_cmap('Greens'))

plt.show()

# %%
plt.figure(1)
plt.subplot(221)
plt.hist(img_green1.ravel(), bins='auto', color="green")  # arguments are passed to np.histogram
plt.subplot(222)
plt.hist(img_green2.ravel(), bins='auto', color="green")  # arguments are passed to np.histogram
plt.subplot(223)
plt.hist(img_green3.ravel(), bins='auto', color="green")  # arguments are passed to np.histogram
plt.subplot(224)
plt.hist(img_green4.ravel(), bins='auto', color="green")  # arguments are passed to np.histogram
plt.show()

# %%
plt.figure(1)
plt.subplot(221)
img_blue1 = B1.astype('int32')
plt.imshow(img_blue1, cmap = plt.get_cmap('Blues'))

plt.subplot(222)
img_blue2 = B2.astype('int32')
plt.imshow(img_blue2, cmap = plt.get_cmap('Blues'))

plt.subplot(223)
img_blue3 = B3.astype('int32')
plt.imshow(img_blue3, cmap = plt.get_cmap('Blues'))

plt.subplot(224)
img_blue4 = B4.astype('int32')
plt.imshow(img_blue4, cmap = plt.get_cmap('Blues'))

plt.show()

# %%
plt.figure(1)
plt.subplot(221)
plt.hist(img_blue1.ravel(), bins='auto', color="blue")  # arguments are passed to np.histogram
plt.subplot(222)
plt.hist(img_blue2.ravel(), bins='auto', color="blue")  # arguments are passed to np.histogram
plt.subplot(223)
plt.hist(img_blue3.ravel(), bins='auto', color="blue")  # arguments are passed to np.histogram
plt.subplot(224)
plt.hist(img_blue4.ravel(), bins='auto', color="blue")  # arguments are passed to np.histogram
plt.show()

# %%
plt.figure(1)
dx = scipy.ndimage.sobel(img_gray1, 0)  # derivada horizontal
dy = scipy.ndimage.sobel(img_gray1, 1)  # derivada vertical
mag1 = np.hypot(dx, dy)  # magnitud
mag1 *= 255.0 / np.max(mag1)  # normalización
plt.subplot(221)
plt.imshow(mag1, cmap = plt.get_cmap('gray'))

dx = scipy.ndimage.sobel(img_gray2, 0)  # derivada horizontal
dy = scipy.ndimage.sobel(img_gray2, 1)  # derivada vertical
mag2 = np.hypot(dx, dy)  # magnitud
mag2 *= 255.0 / np.max(mag2)  # normalización
plt.subplot(222)
plt.imshow(mag2, cmap = plt.get_cmap('gray'))

dx = scipy.ndimage.sobel(img_gray3, 0)  # derivada horizontal
dy = scipy.ndimage.sobel(img_gray3, 1)  # derivada vertical
mag3 = np.hypot(dx, dy)  # magnitud
mag3 *= 255.0 / np.max(mag3)  # normalización
plt.subplot(223)
plt.imshow(mag3, cmap = plt.get_cmap('gray'))


dx = scipy.ndimage.sobel(img_gray4, 0)  # derivada horizontal
dy = scipy.ndimage.sobel(img_gray4, 1)  # derivada vertical
mag4 = np.hypot(dx, dy)  # magnitud
mag4 *= 255.0 / np.max(mag4)  # normalización
plt.subplot(224)
plt.imshow(mag4, cmap = plt.get_cmap('gray'))

plt.show()

# %%
plt.figure(1)
plt.subplot(221)
plt.hist(mag1.ravel(), bins='auto', color="black")  # arguments are passed to np.histogram
plt.subplot(222)
plt.hist(mag2.ravel(), bins='auto', color="black")  # arguments are passed to np.histogram
plt.subplot(223)
plt.hist(mag3.ravel(), bins='auto', color="black")  # arguments are passed to np.histogram
plt.subplot(224)
plt.hist(mag4.ravel(), bins='auto', color="black")  # arguments are passed to np.histogram
plt.show()

# %%
np.histogram(img1)
# Out:
# (array([ 5398, 15406, 15629,  9294,  8959, 14318, 21556, 24729, 27367, 99392]),
#  array([   0. ,   25.5,   51. ,   76.5,  102. ,  127.5,  153. ,  178.5,
#          204. ,  229.5,  255. ]))

# %%
np.histogram(img2)
# Out:
# (array([ 8410, 11513, 14326, 17205, 23141, 22168, 22891, 19310, 24748, 79312]),
#  array([   0. ,   25.5,   51. ,   76.5,  102. ,  127.5,  153. ,  178.5,
#          204. ,  229.5,  255. ]))

# %%
np.histogram(img3)
# Out:
# (array([ 2214, 12502, 23458, 24450, 24270, 23323, 25728, 22605, 13863, 71479]),
#  array([   0. ,   25.5,   51. ,   76.5,  102. ,  127.5,  153. ,  178.5,
#          204. ,  229.5,  255. ]))

# %%
np.histogram(img4)
# Out:
# (array([1030, 2448, 5265, 7401, 9289, 7065, 6744, 1283,  162,   29]),
#  array([   0. ,   23.8,   47.6,   71.4,   95.2,  119. ,  142.8,  166.6,
#          190.4,  214.2,  238. ]))

# %%
#Mean Squared Error 
def mse(imageA, imageB):
    err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
    err /= float(imageA.shape[0] * imageA.shape[1])
    return err

# %%
mse(img1,img2)
# Out:
# 26668.717106143755

# %%
MSEMAT = np.zeros((4,4))

# %%
for i in range(1,5):
    for j in range(1,5):
        text1 = "img%i"%(i)
        text2 = "img%i"%(j)
        print text1,text2
        MSEMAT(i)(j)=mse("img%i","img%i")
# Out:
#   File "<ipython-input-95-5b36a20287cf>", line 6
#     MSEMAT(i)(j)=mse("img%i","img%i")
# SyntaxError: can't assign to function call
